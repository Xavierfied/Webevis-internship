# %%
import cv2 as cv
import yaml
from fsspec.config import conf
from ultralytics import YOLO
from ultralytics.trackers.utils.matching import iou_distance
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Collecting lap>=0.5.12
#   Downloading lap-0.5.13-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy>=1.21.6 in D:\huh\.venv\Lib\site-packages (from lap>=0.5.12) (2.4.2)
# Downloading lap-0.5.13-cp311-cp311-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.5 MB ? eta -:--:--
#    --------------------- ------------------ 0.8/1.5 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 2.5 MB/s  0:00:00
# Installing collected packages: lap
# Successfully installed lap-0.5.13
#
# requirements: AutoUpdate success  8.5s
# WARNING requirements: Restart runtime or rerun command for updates to take effect

# %%
model = YOLO("yolo11n.pt")

# %%
PATH = "img/image1-14.jpeg"
imgg = cv.imread(PATH)

original = imgg.copy()

# %%
cv.imshow("Original", imgg)
cv.waitKey(0)
# Out:
# -1

# %%
result = model(imgg, conf=0.5, iou=0.75)
# Out:
# 0: 480x640 4 persons, 1 car, 2 buss, 139.7ms
# Speed: 98.0ms preprocess, 139.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)

# %%
for box in result[0].boxes:
    x1, y1, x2, y2 = box.xyxy[0].tolist()
    x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

    label = result[0].names[int(box.cls.item())]
    conf = box.conf.item()

    cv.rectangle(imgg, (x1, y1), (x2, y2), (200, 210, 190), 2)
    cv.putText(imgg, f"{label}: {conf:.2f}", (x1, y1), cv.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

cv.imshow("Result", imgg)
cv.waitKey(0)
# Out:
# -1

# %%
cv.imshow("Original", original)
cv.waitKey(0)
# Out:
# -1

# %%
# Out:
# Ultralytics 8.4.19  Python-3.11.8 torch-2.10.0+cpu CPU (Intel Core i7-8850H 2.60GHz)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 metrics = model.val()
#
# File D:\huh\.venv\Lib\site-packages\ultralytics\engine\model.py:614, in Model.val(self, validator, **kwargs)
#     611 args = {**self.overrides, **custom, **kwargs, "mode": "val"}  # highest priority args on the right
#     613 validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 614 validator(model=self.model)
#     615 self.metrics = validator.metrics
#     616 return validator.metrics
#
# File D:\huh\.venv\Lib\site-packages\torch\utils\_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File D:\huh\.venv\Lib\site-packages\ultralytics\engine\validator.py:180, in BaseValidator.__call__(self, trainer, model)
#     177     LOGGER.info(f"Setting batch={self.args.batch} input of shape ({self.args.batch}, 3, {imgsz}, {imgsz})")
#     179 if str(self.args.data).rsplit(".", 1)[-1] in {"yaml", "yml"}:
# --> 180     self.data = check_det_dataset(self.args.data)
#     181 elif self.args.task == "classify":
#     182     self.data = check_cls_dataset(self.args.data, split=self.args.split)
#
# File D:\huh\.venv\Lib\site-packages\ultralytics\data\utils.py:415, in check_det_dataset(dataset, autodownload)
#     401 def check_det_dataset(dataset: str, autodownload: bool = True) -> dict[str, Any]:
#     402     """Download, verify, and/or unzip a dataset if not found locally.
#     403
#     404     This function checks the availability of a specified dataset, and if not found, it has the option to download and
#    (...)    413         (dict[str, Any]): Parsed dataset information and paths.
#     414     """
# --> 415     file = check_file(dataset)
#     417     # Download (optional)
#     418     extract_dir = ""
#
# File D:\huh\.venv\Lib\site-packages\ultralytics\utils\checks.py:682, in check_file(file, suffix, download, download_dir, hard)
#     680 files = glob.glob(str(ROOT / "**" / file), recursive=True) or glob.glob(str(ROOT.parent / file))  # find file
#     681 if not files and hard:
# --> 682     raise FileNotFoundError(f"'{file}' does not exist")
#     683 elif len(files) > 1 and hard:
#     684     raise FileNotFoundError(f"Multiple files match '{file}', specify exact path: {files}")
#
# FileNotFoundError: '/usr/src/ultralytics/ultralytics/cfg/datasets/coco.yaml' does not exist
